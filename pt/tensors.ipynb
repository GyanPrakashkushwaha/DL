# %%
# !pip install torch

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
Q1 = 0.25*58
Q2 = 0.3*70
final = 0.4*85

T = Q1 + Q2 + final 
print(T)
# Out:
# 69.5
